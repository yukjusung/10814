# %% [markdown]
# <a href="https://colab.research.google.com/github/yukjusung/10814/blob/main/20260916.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("재미있는 프로그래밍")
print(5+6)
print(1,2,3,'정보','프로그래밍')
# Out:
# 재미있는 프로그래밍
# 11
# 1 2 3 정보 프로그래밍

# %%
print("품목\t\t가격\t\t개수\n사과\t\t2,000\t\t8\n바나나\t\t3,000\t\t5")
# Out:
# 품목		가격		개수
# 사과		2,000		8
# 바나나		3,000		5

# %%
a=20*30
print(f'20*30={a}')
# Out:
# 20*30=600

# %%
input('나이')
# Out:
# 나이17
# '17'

# %%
a=int(input('입력1'))
b=int(input("입력2"))
print(f"출력{a+b}")
# Out:
# 입력12
# 입력25
# 출력7
